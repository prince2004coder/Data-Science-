# %% [markdown]
# <a href="https://colab.research.google.com/github/prince2004coder/Data-Science-/blob/main/basic%20(lec1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range (0,11,2):
  print(i)

# %%
# @title Default title text
lst = [1, 2, 3,'kiwi', 'c', [2, 3]]
print(lst)


#append. only add single elemnt if we try add more they add list not siongle element

lst.append([2, 3, 4 ])
print(lst)

#extend() add elemntsd of list we add
lst.extend([2, 3, 4])
print(lst)

#insert

lst.insert(2, "value")
print(lst)



#pop
lst.pop()
print(lst)

#remove

lst.remove(2)
print(lst)

#index
lst.index(2)
print(lst.index(2))

#count()

lst.count(3)
print(lst.count(3))

#sort


print(lst)


#sum,min,max,sorted
# Out:
# [1, 2, 3, 'kiwi', 'c', [2, 3]]
# [1, 2, 3, 'kiwi', 'c', [2, 3], [2, 3, 4]]
# [1, 2, 3, 'kiwi', 'c', [2, 3], [2, 3, 4], 2, 3, 4]
# [1, 2, 'value', 3, 'kiwi', 'c', [2, 3], [2, 3, 4], 2, 3, 4]
# [1, 2, 'value', 3, 'kiwi', 'c', [2, 3], [2, 3, 4], 2, 3]
# [1, 'value', 3, 'kiwi', 'c', [2, 3], [2, 3, 4], 2, 3]
# 7
# 2
# [1, 'value', 3, 'kiwi', 'c', [2, 3], [2, 3, 4], 2, 3]

# %%
lst = [1, 2, 3, 4, -1, 0, -4, 5, 6]

sum(lst)
print(sum(lst))



print(min(lst))
print(max(lst))
print(sorted(lst))
# Out:
# 16
# -4
# 6
# [-4, -1, 0, 1, 2, 3, 4, 5, 6]

# %%
lst = [1, 2, 3, 4, -1, 0, -4, 5, 6]

a= sorted(lst)
print(lst)
# Out:
# [1, 2, 3, 4, -1, 0, -4, 5, 6]

# %%
#touples fubnction


#category                functions
#count values.           count ()
#find                    index ()
#size.                   len ()
#total                   sum ()
#highest/lowwest.        max()/min()
# sort                   sorted () (returns list)

# %%
tp= (1, 2, 3, 4, 5 ,6)
print(tp.count(2))


print( tp.index(4))

print(len(tp))


print(sum(tp))


print(max(tp))
print(min(tp))


print(sorted(tp))
# Out:
# 1
# 3
# 6
# 21
# 6
# 1
# [1, 2, 3, 4, 5, 6]

# %%
lst = [1, 2, 3, 4, -1, 0, -4]
lst.sort()
print(lst)
# Out:
# [-4, -1, 0, 1, 2, 3, 4]

# %%
lst1 = [1,2,3,4,5,6]
lst2 = [8,9,7,6,5,4]

result =[]
for i in range (len(lst1)):
    result.append(lst1[i] + lst2[i])
print(result)
# Out:
# [9, 11, 10, 10, 10, 10]

# %%
def fun_name(parameters):
  #body of the function

  def add_numbers(num1, num2):

    return num1 + num2

# %%
# lambda function

x = lambda a,b : b * a
print(x(2,3))
# Out:
# 6

# %%
#string
st = ""
print (len(st))

st = "prince"
st1 = st.upper()
print(st1)

#lower
st = ""
print (len(st))

st = "PRINCE"
st2 = st.lower()
print(st2)

#title
st = ""
print (len(st))

st = "Prince mahur "
st3 = st.title()
print(st3)

st = ""
print (len(st))

st = "prince Mahur"
st4 = st.capitalize()
print(st4)
# Out:
# 0
# PRINCE
# 0
# prince
# 0
# Prince Mahur
# 0
# Prince mahur

# %%
first_name = '  Prince '
last_name = '    Mahur '
#strip


first_name = first_name.strip()
last_name = last_name.strip()

print(first_name + ' ' + last_name)
# Out:
# Prince Mahur

# %%
a = "today "
b= "weather "
c = "is GooD"

st = a + b + c
print(st)


st = st.capitalize()
print(st)

st1 = st.replace("good", "bad")
print(st1)

s = st.startswith("A")
print(s)

s = st.endswith("C")
print(s)
# Out:
# today weather is GooD
# Today weather is good
# Today weather is bad
# False
# False

# %%
st = {2, 2, 23, 3, 2, 1}
print(st)
# Out:
# {1, 2, 3, 23}
