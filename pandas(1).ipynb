# %% [markdown]
# <a href="https://colab.research.google.com/github/prince2004coder/Data-Science-/blob/main/pandas(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

dct = {
    'name' : ['tom', 'nick', 'krish', 'jack'],
    'age' : [20, 21, 19, 18],
    'roll' : [1, 2, 3, 4]
}

df = pd.DataFrame(dct,index=['a','b','c','d'])

#df1 = pd.DataFrame(dct)


display(df)
#display(df1)
# Out:
#     name  age  roll
# a    tom   20     1
# b   nick   21     2
# c  krish   19     3
# d   jack   18     4

# %%
df = pd.read_csv('student_data.csv')
df.head(4)#give first  values you input

df.tail(3)#give last   values you input


df.shape #rows and colums of data we give

#df.info()
#df.describe()
#q1,q2,q3 qualitile ,,,iqr-- q3-q1
#q1,q2,q3---25,50,75(%)


df.columns

df.index

#df[['study_hours','internet_usage']]

#df.study_hours

df.iloc[0:5]#give row data


#df2 = df.loc[df['study_hours']==11]

#df.loc[4]

#df.loc[df['assignments_completed']==8]
#df.iloc[]
# Out:
# study_hours                  11
# attendance                   60
# sleep_hours                   7
# internet_usage                6
# assignments_completed        10
# previous_score               45
# exam_score                100.0
# placement_status         Placed
# Name: 2, dtype: object

# %%
df = pd.read_csv('student_data.csv')

df.loc[df['assignments_completed']==8].iloc[1]
# Out:
# study_hours                   5
# attendance                   52
# sleep_hours                   8
# internet_usage                6
# assignments_completed         8
# previous_score               40
# exam_score                78.82
# placement_status         Placed
# Name: 4, dtype: object

# %%
df = pd.read_csv('student_data.csv')


#df[df['assignments_completed']>8]

df["age"]= 20


#rename columns \


#df.rename(columns = {'assignments_completed':'assign_completed'},inplace = True)
df


df.drop(index=[2],inplace = True)
df.drop(columns= ['age'],inplace = True)
df

df.dropna(inplace = True)
df

df.sort_values(by = 'exam_score',ascending = True,inplace = True)
df

#try isnull,,notnull,unique(for a series. only ),,fillna
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 8805            1          63            4              11
# 186             1          47            5              10
# 3141            1          55            8               8
# 7566            1          58            7               3
# 9499            2          64            5              10
# ...           ...         ...          ...             ...
# 6271            4          59            4              10
# 6274            2          70            7               3
# 6275            9          97            9               4
# 6276           10          70            4               3
# 9993           10          86            9               9
#
#       assignments_completed  previous_score  exam_score placement_status
# 8805                      6              54       26.67       Not Placed
# 186                       0              46       26.89       Not Placed
# ...
